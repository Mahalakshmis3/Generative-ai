# %%
# Install required libraries
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data = {
    'Age': [25, 30, 35, 40, 45, 50, 55, 60, 65, 70],
    'Gender': ['Male', 'Female', 'Female', 'Male', 'Male', 'Female', 'Male', 'Male', 'Female', 'Male'],
    'Income': [50000, 60000, 70000, 80000, 90000, 100000, 110000, 120000, 130000, 140000],
    'Education': ['Bachelor', 'Master', 'PhD', 'Bachelor', 'Master', 'PhD', 'Bachelor', 'Master', 'PhD', 'Bachelor'],
    'Viewership': [1000000, 1500000, 2000000, 2500000, 3000000, 3500000, 4000000, 4500000, 5000000, 5500000]
}
df = pd.DataFrame(data)
print(df.head())
print(df.describe())
sns.histplot(df['Age'], bins=5)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()
gender_counts = df['Gender'].value_counts()
gender_counts.plot(kind='bar')
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()
sns.boxplot(x=df['Income'])
plt.title('Income Distribution')
plt.xlabel('Income')
plt.show()
education_counts = df['Education'].value_counts()
education_counts.plot(kind='barh')
plt.title('Education Level Distribution')
plt.xlabel('Count')
plt.ylabel('Education Level')
plt.show()
sns.scatterplot(data=df, x='Age', y='Viewership', hue='Gender')
plt.title('Viewership vs. Age')
plt.xlabel('Age')
plt.ylabel('Viewership')
plt.legend(title='Gender')
plt.show()
# Out:
# ...
#    Age  Gender  Income Education  Viewership
# 0   25    Male   50000  Bachelor     1000000
# 1   30  Female   60000    Master     1500000
# 2   35  Female   70000       PhD     2000000
# 3   40    Male   80000  Bachelor     2500000
# 4   45    Male   90000    Master     3000000
#              Age         Income    Viewership
# count  10.000000      10.000000  1.000000e+01
# mean   47.500000   95000.000000  3.250000e+06
# std    15.138252   30276.503541  1.513825e+06
# min    25.000000   50000.000000  1.000000e+06
# 25%    36.250000   72500.000000  2.125000e+06
# 50%    47.500000   95000.000000  3.250000e+06
# 75%    58.750000  117500.000000  4.375000e+06
# max    70.000000  140000.000000  5.500000e+06
